# %% [markdown]
# <a href="https://colab.research.google.com/github/fxhxyz4/flux-model-colab/blob/main/flux-model-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rm -rf /content/ComfyUI

# %%
# %cd /content
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# Out:
# /content
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 31545, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 31545 (delta 29), reused 23 (delta 22), pack-reused 31497 (from 3)
# Receiving objects: 100% (31545/31545), 77.21 MiB | 16.00 MiB/s, done.
# Resolving deltas: 100% (21440/21440), done.

# %%
# %cd /content/ComfyUI
# !git pull

# !pip install -r requirements.txt
# Out:
# /content/ComfyUI
# Already up to date.
# ...

# %%
# !pip install -U huggingface_hub
# !hf auth login

# %%
# !pip install -U diffusers transformers accelerate

# %%
# !mkdir -p /content/ComfyUI/models/checkpoints

# !curl -L \
  -H "Authorization: Bearer d4ee5fa6e890b158f37bb568aa9a0ee2" \
  -o /content/ComfyUI/models/checkpoints/pornworks_flux.safetensors \
  https://civitai.com/api/download/models/836198

# %%
import subprocess
import time

PORT = "3000"

comfy_proc = subprocess.Popen(
    ["python3", "main.py", "--listen", "0.0.0.0", "--port", PORT],
    cwd="/content/ComfyUI"
)

subprocess.run(["npm", "install", "-g", "localtunnel"])

lt_proc = subprocess.Popen(
    ["lt", "--port", PORT],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

time.sleep(5)

for _ in range(10):
    line = lt_proc.stdout.readline()
    if "https://" in line:
        print("Public URL:", line.strip())
        break

# %%
# !curl https://loca.lt/mytunnelpassword

# %%
# !ls /content/ComfyUI/models/checkpoints
